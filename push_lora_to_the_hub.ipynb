# %% [markdown]
# <a href="https://colab.research.google.com/github/mightyoctopus/amazon-pricer-model-open-source-fine-tuned-models/blob/main/push_lora_to_the_hub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U peft transformers

# %%
from huggingface_hub import login, upload_folder
from google.colab import userdata, drive
import os

# %%
### LoRA Adapter Path
BASE_PATH = "/content/drive/MyDrive"
PROJECT_NAME = "product-pricer"
ADAPTER_DIR = "product-pricer-2025-12-13_12.35.49/checkpoints"
CHECKPOINT = "checkpoint-4500"

ADAPTER_PATH = f"{BASE_PATH}/{PROJECT_NAME}/{MODEL_DIR}/{CHECKPOINT}"


### Hugging Face URL:
HF_USER = "MightyOctopus"
ADAPTER_NAME = "pricer-lora-ft-v3"
LORA_URL = f"{HF_USER}/{ADAPTER_NAME}"

# %%
HF_TOKEN = userdata.get("HF_TOKEN")
login(HF_TOKEN, add_to_git_credential=True)

# %%
drive.mount("/content/drive/")

# %%
upload_folder(
    folder_path=ADAPTER_PATH,
    repo_id=LORA_URL,
    repo_type="model"
)

print("LoRA adapter successfully pushed!")
